# %%
import pandas as pd
import numpy as np
import seaborn as sns
df = pd.read_csv("C:/Users/prava/Downloads/Walmart (2).csv")
df
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.groupby('Holiday_Flag')

# %%
## Part 1 Walmart
## Question 1 Find the average of total sales for days that are holidays and days that are non-holidays. 
##            Comment on the differences observed (Please refer word document for comments). 

df.groupby('Holiday_Flag').mean().round(2)
# Out:
#               Store  Weekly_Sales  Temperature  Fuel_Price     CPI  \
# Holiday_Flag
# 0              23.0    1041256.38        61.45        3.37  171.60
# 1              23.0    1122887.89        50.23        3.23  171.27
#
#               Unemployment
# Holiday_Flag
# 0                     7.99
# 1                     8.07

# %%
## Part 1 Walmart
## Question 2 Provide descriptive statistics of all features in the dataset (Please refer word document for comments)

df.describe().transpose().round(2)
# Out:
#                count        mean        std        min        25%        50%  \
# Store         6435.0       23.00      12.99       1.00      12.00      23.00
# Weekly_Sales  6435.0  1046964.88  564366.62  209986.25  553350.10  960746.04
# Holiday_Flag  6435.0        0.07       0.26       0.00       0.00       0.00
# Temperature   6435.0       60.66      18.44      -2.06      47.46      62.67
# Fuel_Price    6435.0        3.36       0.46       2.47       2.93       3.44
# CPI           6435.0      171.58      39.36     126.06     131.74     182.62
# Unemployment  6435.0        8.00       1.88       3.88       6.89       7.87
#
#                      75%         max
# Store              34.00       45.00
# Weekly_Sales  1420158.66  3818686.45
# Holiday_Flag        0.00        1.00
# Temperature        74.94      100.14
# Fuel_Price          3.74        4.47
# CPI               212.74      227.23
# Unemployment        8.62       14.31

# %%
## Part 1 Walmart
## Question 3 Complete a correlation matrix and explain the relationship of each feature compared to Sales and whether they are 
##            correlated to each other (Please refer word document for comments).

corr_matrix = df.corr().round(2)
corr_matrix
# Out:
#               Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Store          1.00         -0.34         -0.00        -0.02        0.06
# Weekly_Sales  -0.34          1.00          0.04        -0.06        0.01
# Holiday_Flag  -0.00          0.04          1.00        -0.16       -0.08
# Temperature   -0.02         -0.06         -0.16         1.00        0.14
# Fuel_Price     0.06          0.01         -0.08         0.14        1.00
# CPI           -0.21         -0.07         -0.00         0.18       -0.17
# Unemployment   0.22         -0.11          0.01         0.10       -0.03
#
#                CPI  Unemployment
# Store        -0.21          0.22
# Weekly_Sales -0.07         -0.11
# Holiday_Flag -0.00          0.01
# Temperature   0.18          0.10
# Fuel_Price   -0.17         -0.03
# CPI           1.00         -0.30
# Unemployment -0.30          1.00

# %%
## Part 1 Walmart
## Question 4 Create a scatter plot comparing sales to each feature to visualize the influence it has on sales. 
##            Please elaborate on what you observe (Please refer word document for comments)

import seaborn as sn
import matplotlib.pyplot as plt

# %%
## Comparing sales with stores

import matplotlib.pyplot as plt
plt.scatter(df.Weekly_Sales, df.Store)
plt.show()

# %%
## Comparing sales with Holiday flag (Holiday or Non-Holiday)

plt.scatter(df.Weekly_Sales, df.Holiday_Flag)
plt.show()

# %%
## Comparing sales with Temperature

plt.scatter(df.Weekly_Sales, df.Temperature)
plt.show()

# %%
## Comparing sales with Fuel Price

plt.scatter(df.Weekly_Sales, df.Fuel_Price)
plt.show()

# %%
## Comparing sales with CPI

plt.scatter(df.Weekly_Sales, df.CPI)
plt.show()

# %%
## Comparing sales with Unemployment

plt.scatter(df.Weekly_Sales, df.Unemployment)
plt.show()

# %%
## Question 5 Plot Weekly sales vs date and comment on trends or seasonality that can be observed. 
## (*Hint to do this you will need to aggregate by date and sum the weekly sales numbers) 


df.plot(kind = "line", x = "Date", y = "Weekly_Sales")
plt.show()
